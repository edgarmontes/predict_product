# %%
#!python /content/drive/MyDrive/CEROUNO/CEROUNO/Projects/Project3/final_project/pp_colab.py

# %%
# !cp /content/drive/MyDrive/CEROUNO/CEROUNO/Projects/Project3/final_project/pp_colab_v2.py /content

# %%
import io
import pandas as pd
import pp_colab_v2
from pp_colab_v2 import multi_mod

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3489dd47-3554-4fbf-b67b-ff1682b50f91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3489dd47-3554-4fbf-b67b-ff1682b50f91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving marketing_campaign.csv to marketing_campaign.csv

# %%
#from google.colab import drive
#drive.mount('content/drive')

# %%
df = pd.read_csv(io.StringIO(uploaded["marketing_campaign.csv"].decode("UTF-8")))

# %%
multi_mod(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8aa560328180> in <module>()
# ----> 1 multi_mod(df)
#
# /content/pp_colab_v2.py in multi_mod(df)
#      60     df.dropna(inplace=True)
#      61     #
# ---> 62     df.drop(columns = ['z_costcontact', 'z_revenue'], inplace = True)
#      63     #
#      64     current_date = datetime.datetime.now()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# ...

# %%
for item in df.columns:
  print(item)
# Out:
# id	year_birth	education	marital_status	income	kidhome	teenhome	dt_customer	recency	mntwines	mntfruits	mntmeatproducts	mntfishproducts	mntsweetproducts	mntgoldprods	numdealspurchases	numwebpurchases	numcatalogpurchases	numstorepurchases	numwebvisitsmonth	acceptedcmp3	acceptedcmp4	acceptedcmp5	acceptedcmp1	acceptedcmp2	complain	z_costcontact	z_revenue	response
